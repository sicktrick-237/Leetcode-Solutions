# %%
#!/bin/python

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
    if int(n % 2) == 0 and n in range(2,5):
        print('weird')
    elif
# Out:
# 6
